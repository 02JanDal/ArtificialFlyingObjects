# %% [markdown]
# # Report
#
# Summary your findings and motivate your choice of approach. A better motivation show your understanding of the lab. Dont forget to include the result from part 1!

# %% [markdown]
# **Name:** Jan Dalheimer\
# **Date:** 2022-10-20
#
# ## Introduction
#
# This is the report for lab 1.
#
# ### Exercise 1
#
# I did not manage to complete the full exercise (got completely stuck on implementing `grad_loss`), I feel like I understand the math but my numpy-knowledge wasn't sufficient.
#
# ### Exercise 2
#
# This one wasn't as hard (less numpy-math) however it took quite some time for each training run. I improved the situation by putting the training in a loop, however if I would do this again I would probably do several loops (one for each hyperparameter) and let it run over night, then just work with the resulting losses in various graphs.
#
# ## Result
#
# ### Task 4
#
# #### Step 1 - Perceptron
#
# For a simple perceptron our loss looks as follows:
#
# ![image.png](attachment:c502bdbb-3890-4ce6-82a9-fa12809a1181.png)
#
# There is an indication of possible further improvement with more epochs.
#
# #### Step 2 - MLP
#
# The loss over epochs for a simple MLP looks like this:
#
# ![image.png](attachment:d0984e34-bba7-4c9e-a992-59af3160c894.png)
#
# We can see a slight improvement in loss past the second epoch, however this improvement seems to flatten out already at just 5 epochs.
#
# #### Step 3 - More hidden nodes
#
# For this and the next step I put the training in a loop so that I can train many variants without supervision.
#
# The loss for adding more nodes looks like this:
#
# ![image.png](attachment:749a8dbb-b613-445e-a1d9-8d328bbdf1fa.png)
#
# The loss clearly flattens out at around 5-10 hidden nodes. I find it curious that it seems to flatten out around the same number of nodes as we have classes, this is probably just a coincidance though.
#
# #### Step 4 - More hidden layers
#
# With 10 nodes each:
#
# ![image.png](attachment:c8f1ceb8-6529-4347-ada5-8b0c390a0f8f.png)
# (the title should be "per number of hidden _layers_")
#
# With 4 nodes each:
#
# ![image.png](attachment:99f389d9-7f4e-4035-967d-36844c92b049.png)
#
# From these graphs it actually seems like the loss is increasing with more layers, regardless of the number of nodes. I have not been able to come up with a reasonable explanation for this.
#
# #### Step 5 - Other hyperparameters
#
# I primarily played around a bit with the number of epochs in various combinations with the number of nodes and layers. However, as was already indicated in step 2 the loss flattens out around epoch 5-10 (depending on the number of parameters). My guess is that this is because of the size of the training set, it is possible that a larger training set would be able to be trained further.
#
# I also tested some of the parameters of the optimizer, however I did not really feel like I had enough understanding of them to know how they can be used to improve the training.

# %% [markdown]
# #### Question 1
#
# The feedforward model performed reasonable well however the improvement quickly flattened out. Adding more nodes in the hidden layer improved the achievable loss, however not past 10 hidden nodes.
#
# #### Question 2
#
# Adding more layers, for some reason, made the model perform worse.
#
# #### Question 3
#
# As the optimum seemed to be 5 hidden nodes in just one hidden layer it seems like this is the best. More hidden layers would also lead to a large increase in the number of parameters (`a * b` where `a` is the number of hidden nodes and `b` the number of hidden layers) which would decrease the computational performance of the model.
